# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
fi = np.load("results/basic_exp_09_53_24.npz")

svm_res = fi['svm_res']
svm_cor = svm_res.item()['cor']
svm_pred = svm_res.item()['pred']
print("SVM")
print(svm_pred.shape)
print(svm_cor.shape)

rc_res = fi['rc_res']
rc_cor = rc_res.item()['cor']
rc_pred = rc_res.item()['pred']
print("RC")
print(rc_pred.shape)
print(rc_cor.shape)
# Out:
# SVM
# (1530, 3)
# (1530, 3)
# SVM
# (1530, 3)
# (1530, 3)

# %%
# this matches the test_arg and the pauses are applied correctly
plt.plot(svm_cor)
plt.ylim(-0.1, 1.1)
# Out:
# (-0.1, 1.1)

# %%
plt.plot(svm_pred)

# %%
plt.plot(rc_cor)
plt.ylim(-0.1, 1.1)
# Out:
# (-0.1, 1.1)

# %%
plt.plot(rc_pred)
